# %% [markdown]
# # Capstone Project - The Battle of Neighborhood

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# New York City’s demographics show that it is a large and ethnically diverse metropolis. It is the largest city in the United States with a long history of international immigration. New York City was home to nearly 3.1 million immigrants in 2018, accounting for approximately 37% of the population of the city.
#
# With it’s diverse culture, comes diverse food items. There are many restaurants in New York City, each belonging to different categories like Chinese, Indian, French etc.
#
# So as part of this project, we will list and visualize all major parts of New York City that has Vietnamese restaurants. This will help us to see the potential areas where we can open a Vietnamese restaurant.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# For this project we need following data:
#
# . **New York City's data that contains list Boroughs, Neighborhoods along with their latitude and longitude**: This data set contains the required information. And we will use this data set to explore various neighborhoods of New York city. (Data source : https://cocl.us/new_york_dataset)
#
# . **Vietnamese restaurants in each neighborhood of New York City**: By using API we will get all the venues in each neighborhood. We can filter these venues to get only Vietnamese restaurants. (Data source: Foursquare API)
#
# . **GeoSpace data**: By using this geo space data we will get the New York Borough boundaries that will help us visualize choropleth map. (Data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm)

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# . Collect the New York City data from https://cocl.us/new_york_dataset
# . Using Foursquare API we will find all venues for each neighborhood
# . Filter out all venues that are Vietnamese restaurants
# . Find rating, tips and like counts for each Vietnamese restaurant using Foursquare API
# . Use rating for each restaurant, we will sort that data
# . Visualize the ranking of neighborhoods using folium library (python)
#
# The above-mentioned steps are in order to answer:
#
# 1. What is best location in New York City for Vietnamese Cuisine?
# 2. Which areas have potential Vietnamese restaurant market?
# 3. Which all areas lack Vietnamese restaurants?
# 4. Which is the best place to stay if I prefer Vietnamese Cuisine?

# %% [markdown]
# ## 4. Results

# %% [markdown]
# We see that Manhattan has the largest number of Vietnamese restaurants.

# %%
PATH = "/Users/sony/Desktop/"
Image(filename = PATH + "borough.png", width=800, height=800)

# %% [markdown]
# Chinatown in Manhattan has the most Vietnamese restaurants, respectively three.

# %%
PATH = "/Users/sony/Desktop/"
Image(filename = PATH + "neighborhood.png", width=800, height=800)

# %% [markdown]
# Manhattan has the highest average rating for Vietnamese Restaurants.

# %%
PATH = "/Users/sony/Desktop/"
Image(filename = PATH + "rating.png", width=800, height=800)

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# The ranking is purely on basis of rating of restaurants.
# The accuracy of data depends purely depends on the data provided by FourSquare.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# Chinatown(Manhattan) is the best neighborhoods for Vietnamese cuisine.
# Manhattan have potential Vietnamese Restaurant Market.
# Staten Island ranks last in average rating of Vietnamese Restaurants.
# Manhattan is the best place to stay if you prefer Vietnamese cuisine.
